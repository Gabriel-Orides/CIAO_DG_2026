# %% [markdown]
# # AULA 05 — Particle Swarm Optimization
#
# ## AC-2 — Parte 1
#
# Gabriel Orides - 106541
# Davi Kazussuke - 90613
#
# *Data: 02/09/2026*
#
# Este notebook apresenta a implementação e os resultados das quatro missões propostas na Aula 05.
#
# - Missão 1 — Partícula Solitária;
# - Missão 2 — Enxame / Rosenbrock;
# - Missão 3 — Otimização Logística;
# - Missão 4 — Otimização dos Parâmetros;

# %% [markdown]
# # Missão 1 — A Partícula Solitária
#
# Objetivo: minimizar `f(x) = x²`.
#
# O mínimo global conhecido é `x = 0`.

# %%
# Resultado da Missão 1
 ============================================================
 PARTÍCULA SOLITÁRIA PROcurando o MÍNIMO
============================================================

Posição inicial: 1.0915
Fitness inicial: 1.1914

Iteração  1: pos =  1.8143, fitness =   3.2917
Iteração  2: pos =  1.0631, fitness =   1.1302
Iteração  3: pos =  0.4622, fitness =   0.2136
Iteração  4: pos = -0.0186, fitness =   0.0003
Iteração  5: pos = -0.4032, fitness =   0.1626
Iteração  6: pos =  0.0415, fitness =   0.0017
Iteração  7: pos =  0.2879, fitness =   0.0829
Iteração  8: pos = -0.0389, fitness =   0.0015
Iteração  9: pos = -0.2747, fitness =   0.0754
Iteração 10: pos = -0.3318, fitness =   0.1101
Iteração 11: pos = -0.0464, fitness =   0.0022
Iteração 12: pos =  0.2002, fitness =   0.0401
Iteração 13: pos =  0.2160, fitness =   0.0467
Iteração 14: pos = -0.3669, fitness =   0.1346
Iteração 15: pos = -0.4131, fitness =   0.1707
Iteração 16: pos =  0.2633, fitness =   0.0694
Iteração 17: pos =  0.3710, fitness =   0.1377
Iteração 18: pos = -0.1051, fitness =   0.0111
Iteração 19: pos = -0.2780, fitness =   0.0773
Iteração 20: pos = -0.0659, fitness =   0.0043

============================================================
 RESULTADO FINAL
============================================================
Posição final: -0.065850
Fitness final: 0.004336
Ótimo global: x = 0.000000, f(x) = 0.000000
Erro: 0.065850!

# %% [markdown]
# ## Análise da Missão 1
#
# A partícula utiliza sua posição anterior, velocidade, `pBest` e `gBest` para atualizar seu movimento.
#
# Como existe somente uma partícula, `pBest` e `gBest` correspondem à melhor posição conhecida pela própria partícula.

# %% [markdown]
# # Missão 2 — O Enxame
#
# Nesta missão o PSO é aplicado à função de Rosenbrock:
#
# `f(x,y) = (1-x)² + 100(y-x²)²`
#
# O ótimo global está em `(1,1)`.

# %%
# Resultado da Missão 2

 ============================================================
 PSO - FUNÇÃO DE ROSENBROCK
============================================================
Início: Melhor fitness = 1.380481
Iteração  10: Melhor = 0.037818
Iteração  20: Melhor = 0.032037
Iteração  30: Melhor = 0.018698
Iteração  40: Melhor = 0.002343
Iteração  50: Melhor = 0.001657

Fim: Melhor fitness = 0.001657
Ótimo global: f(1,1) = 0.000000

# %% [markdown]
# ## Análise da Missão 2
#
# O uso de várias partículas permite explorar simultaneamente diferentes regiões do espaço de busca. A informação do `gBest` é compartilhada entre as partículas, favorecendo a convergência.

# %% [markdown]
# # MISSÃO 3 — PROBLEMA CORPORATIVO
# Objetivo
# O problema consiste em localizar 5 centros de distribuição para atender 50 clientes minimizando o custo total de entrega.
#
# O custo é calculado por:
# custo = distância × demanda
#
# Cada cliente é associado ao centro de distribuição mais próximo.

# %%
# Resultado da Missão 3
 ============================================================
 OPTIMUS TECH - LOGÍSTICA INTELIGENTE
============================================================

 DADOS DO PROBLEMA:
   - 50 clientes
   - 5 centros de distribuição
   - Demanda média: 51.0 unidades

 OTIMIZANDO...
  Iteração  20: Custo = 16955.05
  Iteração  40: Custo = 16955.05
  Iteração  60: Custo = 16955.05
  Iteração  80: Custo = 16955.05
  Iteração 100: Custo = 16955.05

 RESULTADO FINAL:
   Tempo de execução: 2.38 segundos
   Custo total: 16955.05
   Melhor custo possível: 0.00
   Centros de distribuição:
      Centro 1: (10.00, 10.00)
      Centro 2: (10.00, 10.00)
      Centro 3: (10.00, 0.00)
      Centro 4: (10.00, 0.00)
      Centro 5: (10.00, 10.00)

# %% [markdown]
# ## Análise da Missão 3
#
# O algoritmo tentou reposicionar os centros, mas não conseguiu escapar do platô inicial e ficou preso em um ótimo local com a configuração padrão, mantendo o custo na faixa de 16955.05 nas 100 iterações avaliadas. Esse resultado mostra que em problemas complexos com variáveis contínuas maiores, a configuração padrão do PSO nem sempre é suficiente e reafirma a importância de tunar os hiperparâmetros (que é exatamente o objetivo da Missão 4).
# Melhorou em relação ao custo inicial: Não.
# Dificuldade: Difícil.

# %% [markdown]
# # Missão 4 — Otimização dos Parâmetros
#
# Foram executadas seis configurações, cada uma com cinco execuções independentes.
# (Nota: Como nosso objetivo logístico é minimizar os gastos, o "Melhor Custo" representa o menor valor numérico, e o "Pior Custo" o maior).

# %%
# Resultado da Missão 4
 ============================================================
 EXPERIMENTOS COM PARÂMETROS DO PSO
============================================================

 Experimento: Padrão
   Parâmetros: w=0.7, c1=1.8, c2=1.8, partículas=30
   Custo médio: 16764.48 ± 1317.48

 Experimento: Inércia Alta
   Parâmetros: w=0.9, c1=1.8, c2=1.8, partículas=30
   Custo médio: 19262.97 ± 1918.66

 Experimento: Inércia Baixa
   Parâmetros: w=0.5, c1=1.8, c2=1.8, partículas=30
   Custo médio: 16386.38 ± 1818.45

 Experimento: Cognitivo Alto
   Parâmetros: w=0.7, c1=2.5, c2=1.8, partículas=30
   Custo médio: 16570.90 ± 2672.41

 Experimento: Social Alto
   Parâmetros: w=0.7, c1=1.8, c2=2.5, partículas=30
   Custo médio: 15812.90 ± 1636.68

 Experimento: Mais Partículas
   Parâmetros: w=0.7, c1=1.8, c2=1.8, partículas=60
   Custo médio: 20164.06 ± 1664.27

============================================================
 ANÁLISE DOS RESULTADOS
============================================================

| Experimento        | Custo Médio | Melhor Custo | Pior Custo  |
|--------------------|-------------|--------------|-------------|
| Padrão             |   16764.48 |     19025.98 |    15443.17 |
| Inércia Alta       |   19262.97 |     21460.47 |    16955.05 |
| Inércia Baixa      |   16386.38 |     19025.98 |    13552.66 |
| Cognitivo Alto     |   16570.90 |     21460.47 |    13552.66 |
| Social Alto        |   15812.90 |     16955.05 |    12756.20 |
| Mais Partículas    |   20164.06 |     21460.47 |    16955.05 |


============================================================
 ANÁLISE E CONCLUSÕES ( PReechido posteriormente via print)
============================================================

1. Qual configuração obteve o MELHOR resultado?
   → Social Alto (com o menor custo médio de 15812.90)

2. Qual configuração obteve o PIOR resultado?
   → Mais Partículas (com o maior custo médio de 20164.06)

3. O que você observou sobre o efeito de:
   - Inércia (w): Aumentar a inércia (0.9) piorou o resultado em relação ao padrão, pois as partículas exploraram demais e demoraram a convergir. A inércia baixa (0.5) melhorou o resultado, mostrando que focar rápido em uma área promissora funcionou bem aqui.
   - Cognitivo (c1): Aumentar o fator cognitivo melhorou levemente o custo médio em relação ao padrão. As partículas confiaram mais em suas próprias descobertas, o que ajudou na exploração inicial antes de seguirem o bando.
   - Social (c2): Teve o impacto mais positivo de todos. Aumentar o fator social fez com que o enxame seguisse rapidamente o 'líder' (gBest), acelerando a convergência para as melhores regiões onde os clientes estavam aglomerados.
   - Número de partículas: Dobrar as partículas para 60 gerou o pior custo. Embora pareça contraintuitivo, ter mais partículas explorando o mapa exige mais iterações para que todas convirjam. Como o limite era de 50 iterações, o enxame acabou se espalhando sem ter tempo de focar no ótimo.

4. Qual configuração você recomenda para este problema? Por quê?
   → Recomendo a configuração 'Social Alto' (w=0.7, c1=1.8, c2=2.5, partículas=30).
   Por quê: Ela alcançou não apenas o menor custo médio geral de entrega, mas também conseguiu encontrar os mínimos mais absolutos. Neste problema logístico específico, permitir que as partículas migrem rapidamente em direção ao centro de distribuição que melhor atende à maioria (gBest) revelou-se a estratégia mais eficiente para reduzir as distâncias dentro do limite de tempo/iterações estabelecido.

# %%
Efeito da inércia (w):
Aumentar a inércia piorou bastante o resultado (Média 19262.97), porque o enxame perdeu a capacidade de focar (explorou excessivamente sem convergir). Diminuir a inércia melhorou o desempenho e achou bons resultados, estabilizando melhor a convergência local.

Efeito cognitivo (c1):
Aumentar para 2.5 ajudou o enxame a descobrir caminhos baratos baseados na experiência individual das próprias partículas, encontrando um dos menores custos gerais.

Efeito social (c2):
Teve o maior impacto positivo. Um valor mais alto fez as partículas seguirem o "líder" rapidamente. Essa forte influência do gBest acelerou a convergência para as regiões com maior concentração de clientes e barateou brutalmente a logística.

Efeito do número de partículas:
O salto para 60 partículas gerou o pior custo médio. Dobrar as partículas significa que o enxame cobre mais área, mas exige um número consideravelmente maior de iterações para todas convergirem para o ponto ótimo. Em apenas 100 iterações, o enxame ficou muito espalhado.

# %% [markdown]
# # Relatório Final
#
# ## O que é PSO?
#
# Particle Swarm Optimization é um algoritmo de otimização baseado no comportamento coletivo de enxames.
#
# Cada partícula representa uma solução candidata e possui uma posição e uma velocidade. A velocidade é influenciada pela experiência individual (`pBest`) e pela experiência coletiva (`gBest`).
#
# ## pBest x gBest
#
# - `pBest`: melhor solução encontrada individualmente por uma partícula.
# - `gBest`: melhor solução encontrada por todo o enxame.
#
# Ambos são importantes porque combinam aprendizado individual e cooperação coletiva.
#
# ## Conclusão
#
# A atividade demonstrou como o PSO pode ser utilizado em diferentes níveis de complexidade, desde uma função matemática simples até um problema de localização de centros de distribuição.
#
# A análise dos parâmetros também mostrou que `w`, `c1`, `c2` e o número de partículas influenciam diretamente o comportamento e o desempenho do algoritmo.
